# %% [markdown]
# # 05 — Evaluation
#
# Runs evaluation and writes a report under `artifacts/<run_id>/`.
#
# This assumes you've already run:
# 1) 02 — Preprocessing
# 2) 03 — Severity Model Training
# 3) 04 — Similarity Retrieval

# %%
from google.colab import drive

drive.mount('/content/drive')

# %cd /content/drive/MyDrive/retrofit

PROJECT_ROOT = '/content/drive/MyDrive/retrofit'
CONFIG = 'configs/colab_large.yaml'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/retrofit

# %%
# !pip -q install -r requirements-colab.txt
# !pip -q install -e .
# Out:
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for bridge-retrofit (pyproject.toml) ... done

# %%
import subprocess
import sys

subprocess.check_call([
    sys.executable, '-m', 'bridge_retrofit.cli',
    '--config', CONFIG,
    '--project-root', PROJECT_ROOT,
    'evaluate',
])
# Out:
# 0
